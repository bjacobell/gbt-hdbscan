# %%
import pybliss
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt

# %%
data_loc = "/datasets/nathan/datasets/voyager_2020_data/"

# The structure here is so each observation target gets a list of files belonging to it
# [[list of on files], [off], [off], [off]]
#
cadence = pybliss.cadence([[f"{data_loc}/single_coarse_guppi_59046_80036_DIAG_VOYAGER-1_0011.rawspec.0000.h5",
                    f"{data_loc}/single_coarse_guppi_59046_80672_DIAG_VOYAGER-1_0013.rawspec.0000.h5",
                    f"{data_loc}/single_coarse_guppi_59046_81310_DIAG_VOYAGER-1_0015.rawspec.0000.h5"
                    ],
                    [f"{data_loc}/single_coarse_guppi_59046_80354_DIAG_VOYAGER-1_0012.rawspec.0000.h5"],
                    [f"{data_loc}/single_coarse_guppi_59046_80989_DIAG_VOYAGER-1_0014.rawspec.0000.h5"],
                    [f"{data_loc}/single_coarse_guppi_59046_81628_DIAG_VOYAGER-1_0016.rawspec.0000.h5"]])

# %%
cadence = pybliss.flaggers.flag_filter_rolloff(cadence, .2)

cadence = pybliss.flaggers.flag_spectral_kurtosis(cadence, .02, 20)
# Out:
# spec kurtosis with M=16 and N=51
# spec kurtosis with M=16 and N=51
# spec kurtosis with M=16 and N=51
# spec kurtosis with M=16 and N=51
# spec kurtosis with M=16 and N=51
# spec kurtosis with M=16 and N=51

# %%
noise_est_options = pybliss.estimators.noise_power_estimate_options()
noise_est_options.masked_estimate = True
noise_est_options.estimator_method = pybliss.estimators.noise_power_estimator.stddev
cadence = pybliss.estimators.estimate_noise_power(cadence, noise_est_options)

# %%
opts = pybliss.integrate_drifts_options()
opts.desmear = True
opts.low_rate = -48
opts.high_rate = 48
opts.rate_step_size = 1

cadence = pybliss.drift_search.integrate_drifts(cadence, opts)
# Out:
# We're doing cpu version
# We're doing cpu version
# We're doing cpu version
# We're doing cpu version
# We're doing cpu version
# We're doing cpu version

# %%
hit_search_opts = pybliss.drift_search.hit_search_options()
hit_search_opts.method = pybliss.drift_search.hit_search_methods.connected_components
hit_search_opts.snr_threshold = 10
cadence = pybliss.drift_search.hit_search(cadence, hit_search_opts)
# Out:
# connected_components looking through 100663296 candidates with threshold 6.21099e+06
# connected_components looking through 100663296 candidates with threshold 1.24494e+07
# connected_components looking through 100663296 candidates with threshold 6.90274e+06
# connected_components looking through 100663296 candidates with threshold 2.11755e+07
# connected_components looking through 100663296 candidates with threshold 1.02085e+07
# connected_components looking through 100663296 candidates with threshold 6.10186e+06

# %%
events = pybliss.drift_search.event_search(cadence)
for e in events:
    print(e)
# Out:
# event: .starting_frequency_Hz=8419565239 .average_drift_rate_Hz_per_sec=-0.36.average_power=0 .average_snr=905.716 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.565239 (.index=651993), .drift_rate_Hz_per_second=-0.344394 (.index=84), .SNR=1641.192017, .power=0, bandwidth=399.5", "hit: .start_freq_MHz=8419.564990 (.index=651965), .drift_rate_Hz_per_second=-0.353960 (.index=85), .SNR=216.908142, .power=0, bandwidth=332.5", "hit: .start_freq_MHz=8419.564736 (.index=652171), .drift_rate_Hz_per_second=-0.392226 (.index=89), .SNR=859.046692, .power=0, bandwidth=385.6"}]Event was found in an off scan
# Event was found in an off scan
#
# event: .starting_frequency_Hz=8419542734 .average_drift_rate_Hz_per_sec=-0.37.average_power=0 .average_snr=59549.9 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.542734 (.index=659988), .drift_rate_Hz_per_second=-0.344394 (.index=84), .SNR=110775.031250, .power=0, bandwidth=55.9", "hit: .start_freq_MHz=8419.542493 (.index=660074), .drift_rate_Hz_per_second=-0.353960 (.index=85), .SNR=12183.276367, .power=0, bandwidth=16.8", "hit: .start_freq_MHz=8419.542239 (.index=660165), .drift_rate_Hz_per_second=-0.411359 (.index=91), .SNR=55691.289062, .power=0, bandwidth=25.1"}]
# event: .starting_frequency_Hz=8419520239 .average_drift_rate_Hz_per_sec=-0.37.average_power=0 .average_snr=860.085 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.520239 (.index=668097), .drift_rate_Hz_per_second=-0.344394 (.index=84), .SNR=1521.325684, .power=0, bandwidth=410.7", "hit: .start_freq_MHz=8419.519993 (.index=668069), .drift_rate_Hz_per_second=-0.353960 (.index=85), .SNR=191.791672, .power=0, bandwidth=335.3", "hit: .start_freq_MHz=8419.519742 (.index=668275), .drift_rate_Hz_per_second=-0.401793 (.index=90), .SNR=867.137695, .power=0, bandwidth=388.4"}]
# event: .starting_frequency_Hz=8419610244 .average_drift_rate_Hz_per_sec=0.18.average_power=0 .average_snr=11.5836 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.610244 (.index=635825), .drift_rate_Hz_per_second=0.200896 (.index=27), .SNR=11.722090, .power=0, bandwidth=0.0", "hit: .start_freq_MHz=8419.609593 (.index=636058), .drift_rate_Hz_per_second=0.162630 (.index=31), .SNR=11.445020, .power=0, bandwidth=0.0"}]
# event: .starting_frequency_Hz=8419610225 .average_drift_rate_Hz_per_sec=0.13.average_power=0 .average_snr=11.6266 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.610225 (.index=635832), .drift_rate_Hz_per_second=0.124364 (.index=35), .SNR=11.463636, .power=0, bandwidth=0.0", "hit: .start_freq_MHz=8419.609535 (.index=636079), .drift_rate_Hz_per_second=0.143497 (.index=33), .SNR=11.789644, .power=0, bandwidth=0.0"}]
# event: .starting_frequency_Hz=8419610297 .average_drift_rate_Hz_per_sec=0.05.average_power=0 .average_snr=10.3074 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.610297 (.index=635806), .drift_rate_Hz_per_second=0.047832 (.index=43), .SNR=10.501421, .power=0, bandwidth=0.0", "hit: .start_freq_MHz=8419.609610 (.index=636052), .drift_rate_Hz_per_second=0.057399 (.index=42), .SNR=10.113443, .power=0, bandwidth=0.0"}]
# event: .starting_frequency_Hz=8419610225 .average_drift_rate_Hz_per_sec=-0.25.average_power=0 .average_snr=12.4931 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.610225 (.index=635832), .drift_rate_Hz_per_second=-0.095665 (.index=58), .SNR=11.010799, .power=0, bandwidth=0.0", "hit: .start_freq_MHz=8419.609889 (.index=635952), .drift_rate_Hz_per_second=-0.401793 (.index=90), .SNR=13.975365, .power=0, bandwidth=2.8"}]
# event: .starting_frequency_Hz=8419610322 .average_drift_rate_Hz_per_sec=-0.25.average_power=0 .average_snr=13.0215 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.610322 (.index=635797), .drift_rate_Hz_per_second=-0.105231 (.index=59), .SNR=11.268890, .power=0, bandwidth=0.0", "hit: .start_freq_MHz=8419.609568 (.index=636067), .drift_rate_Hz_per_second=-0.392226 (.index=89), .SNR=14.774192, .power=0, bandwidth=5.6"}]
# event: .starting_frequency_Hz=8419519728 .average_drift_rate_Hz_per_sec=-0.28.average_power=0 .average_snr=13.295 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.519728 (.index=668218), .drift_rate_Hz_per_second=-0.162630 (.index=65), .SNR=11.900705, .power=0, bandwidth=22.4", "hit: .start_freq_MHz=8419.519259 (.index=668390), .drift_rate_Hz_per_second=-0.392226 (.index=89), .SNR=14.689318, .power=0, bandwidth=0.0"}]
# event: .starting_frequency_Hz=8419565711 .average_drift_rate_Hz_per_sec=-0.37.average_power=0 .average_snr=22.7528 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.565711 (.index=651764), .drift_rate_Hz_per_second=-0.344394 (.index=84), .SNR=30.450813, .power=0, bandwidth=5.6", "hit: .start_freq_MHz=8419.565211 (.index=651942), .drift_rate_Hz_per_second=-0.392226 (.index=89), .SNR=15.054782, .power=0, bandwidth=5.6"}]
# event: .starting_frequency_Hz=8419475402 .average_drift_rate_Hz_per_sec=-0.37.average_power=0 .average_snr=19.062 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.475402 (.index=684087), .drift_rate_Hz_per_second=-0.344394 (.index=84), .SNR=25.309118, .power=0, bandwidth=2.8", "hit: .start_freq_MHz=8419.474904 (.index=684265), .drift_rate_Hz_per_second=-0.392226 (.index=89), .SNR=12.814946, .power=0, bandwidth=2.8"}]
# event: .starting_frequency_Hz=8419564750 .average_drift_rate_Hz_per_sec=-0.38.average_power=0 .average_snr=21.2408 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.564750 (.index=652108), .drift_rate_Hz_per_second=-0.344394 (.index=84), .SNR=25.977535, .power=0, bandwidth=5.6", "hit: .start_freq_MHz=8419.564258 (.index=652285), .drift_rate_Hz_per_second=-0.411359 (.index=91), .SNR=16.504148, .power=0, bandwidth=2.8"}]
# event: .starting_frequency_Hz=8419475050 .average_drift_rate_Hz_per_sec=-0.31.average_power=0 .average_snr=15.3567 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.475050 (.index=684213), .drift_rate_Hz_per_second=-0.210463 (.index=70), .SNR=10.313688, .power=0, bandwidth=0.0", "hit: .start_freq_MHz=8419.474586 (.index=684379), .drift_rate_Hz_per_second=-0.401793 (.index=90), .SNR=20.399712, .power=0, bandwidth=5.6"}]
# event: .starting_frequency_Hz=8419520717 .average_drift_rate_Hz_per_sec=-0.35.average_power=0 .average_snr=20.905 .event_start_seconds=5.10165e+09 .event_end_seconds=5.10165e+09
# .hits=[{"hit: .start_freq_MHz=8419.520717 (.index=667868), .drift_rate_Hz_per_second=-0.344394 (.index=84), .SNR=25.649006, .power=0, bandwidth=5.6", "hit: .start_freq_MHz=8419.520211 (.index=668049), .drift_rate_Hz_per_second=-0.353960 (.index=85), .SNR=16.160994, .power=0, bandwidth=0.0"}]
# Event was found in an off scan
# Average SNR of this candidate event is 905.716 and drift is -0.363527
# Average SNR of this candidate event is 59549.9 and drift is -0.369904
# Average SNR of this candidate event is 860.085 and drift is -0.366715
# Average SNR of this candidate event is 11.5836 and drift is 0.181763
# Average SNR of this candidate event is 11.6266 and drift is 0.133931
# Average SNR of this candidate event is 10.3074 and drift is 0.0526157
# Average SNR of this candidate event is 12.4931 and drift is -0.248729
# Average SNR of this candidate event is 13.0215 and drift is -0.248729
# Average SNR of this candidate event is 13.295 and drift is -0.277428
# Average SNR of this candidate event is 22.7528 and drift is -0.36831
# Average SNR of this candidate event is 19.062 and drift is -0.36831
# Average SNR of this candidate event is 21.2408 and drift is -0.377876
# Average SNR of this candidate event is 15.3567 and drift is -0.306128
# Average SNR of this candidate event is 20.905 and drift is -0.349177

# %%
flattened_scans = [scan for observation in cadence.observations for scan in observation.scans]
flattened_scans = sorted(flattened_scans, key=lambda x: x.tstart)

# %%
# fig, (axes) = plt.subplots(6, 2, sharex=True)
n_plots = 6
fig, axes = plt.subplots(1+n_plots, 1, sharex=True, sharey=False, figsize=(10, 2*n_plots))

plt.suptitle("BL GBT Coarse Channel of Voyager-1")

for nn, plot_scan in enumerate(flattened_scans):
    plot_data = np.from_dlpack(plot_scan.data)

    fch1 = plot_scan.fch1
    print(fch1)
    foff = plot_scan.foff
    print(foff)
    nchans = plot_scan.nchans
    freqs = np.linspace(fch1, fch1 + foff * nchans, nchans)
    print(np.min(freqs))
    print(np.max(freqs))


    axes[0].plot(freqs, 10* np.log10(plot_data.mean(0)))
    # axes[nn,0].set_ylabel("Power [dB]")

    start_time = plot_scan.tstart * 24 * 60 * 60
    end_time = start_time + plot_scan.tsamp * plot_data.shape[0]
    axes[nn+1].imshow(10*np.log10(plot_data), aspect="auto", interpolation=None, cmap="turbo", extent=[freqs[0], freqs[-1], end_time, start_time])
    axes[nn+1].set_ylabel("Time")

    for e in events:
        start_freq = e.starting_frequency_Hz + (start_time - e.event_start_seconds) * e.average_drift_rate_Hz_per_sec
        end_freq = start_freq + (end_time - start_time) * e.average_drift_rate_Hz_per_sec
        color = "red"
        if len(e.hits) == 2:
            color = "yellow"
        axes[nn+1].plot((start_freq/1e6, end_freq/1e6), (start_time, end_time), ls='dashed', lw=1, color=color)

plt.margins(0)
plt.subplots_adjust(hspace=0,wspace=0)


plt.xlabel("Frequency [MHz]")
# Out:
# 8421.38671875
# -2.7939677238464355e-06
# 8418.45703125
# 8421.38671875
# /usr/local/lib/python3.10/dist-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /usr/local/lib/python3.10/dist-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# 8421.38671875
# -2.7939677238464355e-06
# 8418.45703125
# 8421.38671875
# 8421.38671875
# -2.7939677238464355e-06
# 8418.45703125
# 8421.38671875
# 8421.38671875
# -2.7939677238464355e-06
# 8418.45703125
# 8421.38671875
# 8421.38671875
# -2.7939677238464355e-06
# 8418.45703125
# 8421.38671875
# 8421.38671875
# -2.7939677238464355e-06
# 8418.45703125
# 8421.38671875
# Text(0.5, 0, 'Frequency [MHz]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
axes[0].legend(["scan 0", "scan 1", "scan 2", "scan 3", "scan 4", "scan 5", ])
